# %%
import pubchempy as pcp
import pandas as pd
import random, time

# %%
compoundnames = pd.read_csv("ComboCompoundNames_small.txt", sep='\t')

# %%
for x in set(compoundnames['Drug'].unique()): print(x)

# %%
# 用pubchem搜索ichikey
#https://pubchem.ncbi.nlm.nih.gov/idexchange/idexchange.cgi

# %%
helper4ichikey = pd.read_csv("helper4R.txt",sep='\t', header=None)
helper4ichikey.columns = ['drug_name',"ichikey"]
helper4ichikey = helper4ichikey.drop_duplicates(subset=['drug_name'], keep="first")

# %%
helper4ichikey
# Out:
#                     drug_name                      ichikey
# 0                 Clofarabine  WDDPHFBMKLOVOX-AYQXTPAHSA-N
# 1    Raloxifene hydrochloride  BKXVVCILCIUCLG-UHFFFAOYSA-N
# 2                  Nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N
# 3                   Etoposide  VJJPUSNTGOMMGY-MRVIYFEKSA-N
# 4        Lapatinib ditosylate  UWYXLGUQQFPJRI-UHFFFAOYSA-N
# ..                        ...                          ...
# 178       Triethylenemelamine  IUCJMVBFZDHPDX-UHFFFAOYSA-N
# 179               Azacitidine  NMUSYJAQQFHJEW-KVTDHHQDSA-N
# 180                  Busulfan  COVZYZSDYWQREU-UHFFFAOYSA-N
# 181   Topotecan hydrochloride  DGHHQBMTXTWTJV-BQAIUKQQSA-N
# 182  Quinacrine hydrochloride  UDKVBVICMUEIKS-UHFFFAOYSA-N
#
# [104 rows x 2 columns]

# %%
for x in helper4ichikey['ichikey']: print(x)
    # 用classifire搜索
    #https://cfb.fiehnlab.ucdavis.edu/

# %%
batch_classifire = pd.read_csv("classyfire_.csv")

# %%
pd.merge(helper4ichikey,batch_classifire,left_on='ichikey',right_on='InChIKey')
# Out:
#                     drug_name                      ichikey  \
# 0                 Clofarabine  WDDPHFBMKLOVOX-AYQXTPAHSA-N
# 1    Raloxifene hydrochloride  BKXVVCILCIUCLG-UHFFFAOYSA-N
# 2                  Nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N
# 3                   Etoposide  VJJPUSNTGOMMGY-MRVIYFEKSA-N
# 4        Lapatinib ditosylate  UWYXLGUQQFPJRI-UHFFFAOYSA-N
# ..                        ...                          ...
# 99        Triethylenemelamine  IUCJMVBFZDHPDX-UHFFFAOYSA-N
# 100               Azacitidine  NMUSYJAQQFHJEW-KVTDHHQDSA-N
# 101                  Busulfan  COVZYZSDYWQREU-UHFFFAOYSA-N
# 102   Topotecan hydrochloride  DGHHQBMTXTWTJV-BQAIUKQQSA-N
# 103  Quinacrine hydrochloride  UDKVBVICMUEIKS-UHFFFAOYSA-N
#
#                         InChIKey ClassyFy Status            Kingdom  \
# 0    WDDPHFBMKLOVOX-AYQXTPAHSA-N       Completed  Organic compounds
# 1    BKXVVCILCIUCLG-UHFFFAOYSA-N       Completed  Organic compounds
# 2    IXOXBSCIXZEQEQ-UHTZMRCNSA-N       Completed  Organic compounds
# 3    VJJPUSNTGOMMGY-MRVIYFEKSA-N       Completed  Organic compounds
# 4    UWYXLGUQQFPJRI-UHFFFAOYSA-N       Completed  Organic compounds
# ..                           ...             ...                ...
# 99   IUCJMVBFZDHPDX-UHFFFAOYSA-N       Completed  Organic compounds
# 100  NMUSYJAQQFHJEW-KVTDHHQDSA-N       Completed  Organic compounds
# 101  COVZYZSDYWQREU-UHFFFAOYSA-N       Completed  Organic compounds
# 102  DGHHQBMTXTWTJV-BQAIUKQQSA-N       Completed  Organic compounds
# 103  UDKVBVICMUEIKS-UHFFFAOYSA-N       Completed  Organic compounds
#
#                                     Superclass  \
# 0      Nucleosides, nucleotides, and analogues
# 1                     Organic oxygen compounds
# 2      Nucleosides, nucleotides, and analogues
# 3    Lignans, neolignans and related compounds
# 4                 Organoheterocyclic compounds
# ..                                         ...
# 99                  Organic nitrogen compounds
# 100                   Organic oxygen compounds
# 101              Organic acids and derivatives
# 102                  Alkaloids and derivatives
# 103               Organoheterocyclic compounds
#
#                                       Class  \
# 0                        Purine nucleosides
# 1                    Organooxygen compounds
# 2                        Purine nucleosides
# 3                           Lignan lactones
# 4                         Diazanaphthalenes
# ..                                      ...
# 99                 Organonitrogen compounds
# 100                  Organooxygen compounds
# 101  Organic sulfonic acids and derivatives
# 102                           Camptothecins
# 103              Quinolines and derivatives
#
#                                       Subclass  \
# 0               Purine 2'-deoxyribonucleosides
# 1                           Carbonyl compounds
# 2                                          NaN
# 3                             Podophyllotoxins
# 4                                Benzodiazines
# ..                                         ...
# 99                                      Amines
# 100  Carbohydrates and carbohydrate conjugates
# 101       Organosulfonic acids and derivatives
# 102                                        NaN
# 103                            Benzoquinolines
#
#                      Parent Level 1            Parent Level 2  \
# 0    Purine 2'-deoxyribonucleosides                       NaN
# 1                           Ketones              Aryl ketones
# 2                Purine nucleosides                       NaN
# 3                  Podophyllotoxins                       NaN
# 4                      Quinazolines          Quinazolinamines
# ..                              ...                       ...
# 99                  Tertiary amines  Tertiary alkylarylamines
# 100              Glycosyl compounds            Glycosylamines
# 101      Organosulfonic acid esters                       NaN
# 102                   Camptothecins                       NaN
# 103                       Acridines                       NaN
#
#         Parent Level 3      Parent Level 4
# 0                  NaN                 NaN
# 1        Phenylketones  Aryl-phenylketones
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ..                 ...                 ...
# 99   Dialkylarylamines                 NaN
# 100                NaN                 NaN
# 101                NaN                 NaN
# 102                NaN                 NaN
# 103                NaN                 NaN
#
# [104 rows x 12 columns]

# %% [markdown]
# ### convert web crawler drugs/ almanac combo score's drugs to pubchemID

# %%
dcdb_score = pd.read_csv("dcdb_crawler_almanac_withID.csv")

# %%
dcdb_score
# Out:
#                            drug1       drug2         cellName        HSA  \
# 0       CYTARABINE HYDROCHLORIDE   NSC733504         NCI-H226   0.066454
# 1       CYTARABINE HYDROCHLORIDE   NSC733504          UACC-62   0.380613
# 2       CYTARABINE HYDROCHLORIDE   NSC733504             EKVX   0.189652
# 3       CYTARABINE HYDROCHLORIDE   NSC733504           DU-145   2.099788
# 4       CYTARABINE HYDROCHLORIDE   NSC733504         COLO 205  -1.705684
# ...                          ...         ...              ...        ...
# 311593                VANDETANIB  RALOXIFENE         SK-MEL-2   6.820279
# 311594                VANDETANIB  RALOXIFENE        SK-MEL-28  11.322946
# 311595                VANDETANIB  RALOXIFENE          OVCAR-3   4.320625
# 311596                VANDETANIB  RALOXIFENE  MDA-MB-231/ATCC  -3.387792
# 311597                VANDETANIB  RALOXIFENE          HS 578T   8.615710
#
#             Bliss      Loewe        ZIP        pubchemID_x        pubchemID_y
# 0        1.101240  -3.895015  -0.672448     Compound(6252)  Compound(6442177)
# 1        1.906991  -0.833887  -3.006925     Compound(6252)  Compound(6442177)
# 2        2.822932   0.167852  -0.210029     Compound(6252)  Compound(6442177)
# 3        2.798682  -0.809267  -2.782032     Compound(6252)  Compound(6442177)
# 4       -2.431513  -4.283340  -0.498853     Compound(6252)  Compound(6442177)
# ...           ...        ...        ...                ...                ...
# 311593  10.025902   7.121419   5.184792  Compound(3081361)     Compound(5035)
# 311594  16.658387  12.057066  10.760758  Compound(3081361)     Compound(5035)
# 311595   4.507935  -1.746247  -0.369569  Compound(3081361)     Compound(5035)
# 311596  -1.650064  -6.333952  -1.144886  Compound(3081361)     Compound(5035)
# 311597  15.743034   8.869470   9.416326  Compound(3081361)     Compound(5035)
#
# [311598 rows x 9 columns]

# %%
def get_uniquedrug(subsetdf):
    drug_list = []
    drug1_dc = subsetdf["drug1"].unique()
    drug2_dc = subsetdf["drug2"].unique()
    
    drug_list.append(set(drug1_dc))
    drug_list.append(set(drug2_dc))
    return drug_list

# %%
drug_list = get_uniquedrug(dcdb_score)
# One-Liner to union a list of sets
drug_list_set = set().union(*drug_list)

# %%
len(drug_list_set)
# Out:
# 103

# %%
# 1. get pubchemID for each unique drug by using PubChem API

def get_compounds(a_drug):
    return pcp.get_compounds(a_drug, 'name',listkey_count=1)

def get_pubchemID(drug_list_set):
    chemID_list = [ get_compounds(x)[0] if len(get_compounds(x))>0 else "" for x in drug_list_set if time.sleep(0.5) is None]
    print(x for x in drug_list_set)
    return chemID_list

chemID_list = get_pubchemID(drug_list_set)
pubchemIDmapping = pd.DataFrame({
    'drug_name': list(drug_list_set),
    'pubchemID': chemID_list
})
pubchemIDmapping['pubchemID'] = pubchemIDmapping['pubchemID'].astype(str)
# Out:
# <generator object get_pubchemID.<locals>.<genexpr> at 0x7f79fa913ad0>

# %%
# pubchemIDmapping.to_csv("pubchemIDmapping_dcdb.csv")
# pubchemIDmapping
pubchemIDmapping = pd.read_csv("pubchemIDmapping_dcdb.csv")

# %%
pubchemIDmapping
# Out:
#                     drug_name           pubchemID
# 0                  34793-34-5   Compound(3011155)
# 1    5-FLUORO-2'-DEOXYURIDINE      Compound(5790)
# 2                        5-FU      Compound(3385)
# 3                 ABIRATERONE    Compound(132971)
# 4               ACTINOMYCIN D    Compound(457193)
# ..                        ...                 ...
# 98        VINBLASTINE SULFATE    Compound(241902)
# 99        VINCRISTINE SULFATE    Compound(249332)
# 100                VISMODEGIB  Compound(24776445)
# 101           ZOLEDRONIC ACID     Compound(68740)
# 102                   ZOLINZA      Compound(5311)
#
# [103 rows x 2 columns]

# %%
dcdb_score  = dcdb_score[['drug1','drug2','cellName','HSA','Bliss','Loewe','ZIP']]
dcdb_score
# Out:
#                            drug1       drug2         cellName        HSA  \
# 0       CYTARABINE HYDROCHLORIDE   NSC733504         NCI-H226   0.066454
# 1       CYTARABINE HYDROCHLORIDE   NSC733504          UACC-62   0.380613
# 2       CYTARABINE HYDROCHLORIDE   NSC733504             EKVX   0.189652
# 3       CYTARABINE HYDROCHLORIDE   NSC733504           DU-145   2.099788
# 4       CYTARABINE HYDROCHLORIDE   NSC733504         COLO 205  -1.705684
# ...                          ...         ...              ...        ...
# 311593                VANDETANIB  RALOXIFENE         SK-MEL-2   6.820279
# 311594                VANDETANIB  RALOXIFENE        SK-MEL-28  11.322946
# 311595                VANDETANIB  RALOXIFENE          OVCAR-3   4.320625
# 311596                VANDETANIB  RALOXIFENE  MDA-MB-231/ATCC  -3.387792
# 311597                VANDETANIB  RALOXIFENE          HS 578T   8.615710
#
#             Bliss      Loewe        ZIP
# 0        1.101240  -3.895015  -0.672448
# 1        1.906991  -0.833887  -3.006925
# 2        2.822932   0.167852  -0.210029
# 3        2.798682  -0.809267  -2.782032
# 4       -2.431513  -4.283340  -0.498853
# ...           ...        ...        ...
# 311593  10.025902   7.121419   5.184792
# 311594  16.658387  12.057066  10.760758
# 311595   4.507935  -1.746247  -0.369569
# 311596  -1.650064  -6.333952  -1.144886
# 311597  15.743034   8.869470   9.416326
#
# [311598 rows x 7 columns]

# %%
temp1_dc = pd.merge(dcdb_score, pubchemIDmapping, left_on=['drug1'],right_on=['drug_name'])
temp2_dc = pd.merge(temp1_dc, pubchemIDmapping, left_on=['drug2'],right_on=['drug_name'])

# %%
temp2_dc[['drug1','drug2','cellName','HSA','Bliss','Loewe','ZIP','pubchemID_x','pubchemID_y']].to_csv("dcdb_crawler_almanac_withID.csv")

# %%
combo_score = pd.read_csv("long_DTP_NCI60_ALMANAC_COMBO_SCORE.csv")
combo_score
# Out:
#           NSC1    NSC2    CELLNAME  COMBO_SCORE         drug1        drug2
# 0          740     752        MCF7        -57.0  METHOTREXATE  THIOGUANINE
# 1          740     752  MDA-MB-231         19.0  METHOTREXATE  THIOGUANINE
# 2          740     752     HS 578T          8.0  METHOTREXATE  THIOGUANINE
# 3          740     752      BT-549        -33.0  METHOTREXATE  THIOGUANINE
# 4          740     752       T-47D        -89.0  METHOTREXATE  THIOGUANINE
# ...        ...     ...         ...          ...           ...          ...
# 321295  763371  761432      CAKI-1          5.0   RUXOLITINIB  CABAZITAXEL
# 321296  763371  761432     RXF 393         36.0   RUXOLITINIB  CABAZITAXEL
# 321297  763371  761432       SN12C         65.0   RUXOLITINIB  CABAZITAXEL
# 321298  763371  761432       TK-10         75.0   RUXOLITINIB  CABAZITAXEL
# 321299  763371  761432       UO-31         71.0   RUXOLITINIB  CABAZITAXEL
#
# [321300 rows x 6 columns]

# %%
drug_list = get_uniquedrug(combo_score)
# One-Liner to union a list of sets
drug_list_set = set().union(*drug_list)

# %%
len(drug_list_set)
# Out:
# 104

# %%
def get_compounds(a_drug):
    return pcp.get_compounds(a_drug, 'name',listkey_count=1)

def get_pubchemID(drug_list_set):
    chemID_list = [ get_compounds(x)[0] if len(get_compounds(x))>0 else "" for x in drug_list_set if time.sleep(0.5) is None]
    print(x for x in drug_list_set)
    return chemID_list

chemID_list = get_pubchemID(drug_list_set)
pubchemIDmapping = pd.DataFrame({
    'drug_name': list(drug_list_set),
    'pubchemID': chemID_list
})
pubchemIDmapping['pubchemID'] = pubchemIDmapping['pubchemID'].astype(str)
# Out:
# <generator object get_pubchemID.<locals>.<genexpr> at 0x7f79fcbeb450>

# %%
# pubchemIDmapping.to_csv("pubchemIDmapping_comboscore.csv")
# pubchemIDmapping
pubchemIDmapping = pd.read_csv("pubchemIDmapping_comboscore.csv")
pubchemIDmapping
# Out:
#                           drug_name            pubchemID
# 0                    2-FLUORO ARA-A     Compound(657237)
# 1                  4'-EPIADRIAMYCIN      Compound(41867)
# 2    7-ETHYL-10-HYDROXYCAMPTOTHECIN     Compound(104842)
# 3                       ABIRATERONE     Compound(132971)
# 4                       ALLOPURINOL  Compound(135401907)
# ..                              ...                  ...
# 99              VINCRISTINE SULFATE     Compound(249332)
# 100            VINORELBINE TARTRATE   Compound(11607738)
# 101                      VISMODEGIB   Compound(24776445)
# 102                      VORINOSTAT       Compound(5311)
# 103                 ZOLEDRONIC ACID      Compound(68740)
#
# [104 rows x 2 columns]

# %%
temp1_dc = pd.merge(combo_score, pubchemIDmapping, left_on=['drug1'],right_on=['drug_name'])
temp2_dc = pd.merge(temp1_dc, pubchemIDmapping, left_on=['drug2'],right_on=['drug_name'])

# %%
temp2_dc
# Out:
#           NSC1    NSC2    CELLNAME  COMBO_SCORE             drug1  \
# 0          740     752        MCF7        -57.0      METHOTREXATE
# 1          740     752  MDA-MB-231         19.0      METHOTREXATE
# 2          740     752     HS 578T          8.0      METHOTREXATE
# 3          740     752      BT-549        -33.0      METHOTREXATE
# 4          740     752       T-47D        -89.0      METHOTREXATE
# ...        ...     ...         ...          ...               ...
# 321295  256942  256439      CAKI-1        -35.0  4'-EPIADRIAMYCIN
# 321296  256942  256439     RXF 393        -25.0  4'-EPIADRIAMYCIN
# 321297  256942  256439       SN12C        -62.0  4'-EPIADRIAMYCIN
# 321298  256942  256439       TK-10         73.0  4'-EPIADRIAMYCIN
# 321299  256942  256439       UO-31         42.0  4'-EPIADRIAMYCIN
#
#                            drug2       drug_name_x       pubchemID_x  \
# 0                    THIOGUANINE      METHOTREXATE  Compound(126941)
# 1                    THIOGUANINE      METHOTREXATE  Compound(126941)
# 2                    THIOGUANINE      METHOTREXATE  Compound(126941)
# 3                    THIOGUANINE      METHOTREXATE  Compound(126941)
# 4                    THIOGUANINE      METHOTREXATE  Compound(126941)
# ...                          ...               ...               ...
# 321295  IDARUBICIN HYDROCHLORIDE  4'-EPIADRIAMYCIN   Compound(41867)
# 321296  IDARUBICIN HYDROCHLORIDE  4'-EPIADRIAMYCIN   Compound(41867)
# 321297  IDARUBICIN HYDROCHLORIDE  4'-EPIADRIAMYCIN   Compound(41867)
# 321298  IDARUBICIN HYDROCHLORIDE  4'-EPIADRIAMYCIN   Compound(41867)
# 321299  IDARUBICIN HYDROCHLORIDE  4'-EPIADRIAMYCIN   Compound(41867)
#
#                      drug_name_y        pubchemID_y
# 0                    THIOGUANINE  Compound(2723601)
# 1                    THIOGUANINE  Compound(2723601)
# 2                    THIOGUANINE  Compound(2723601)
# 3                    THIOGUANINE  Compound(2723601)
# 4                    THIOGUANINE  Compound(2723601)
# ...                          ...                ...
# 321295  IDARUBICIN HYDROCHLORIDE    Compound(42890)
# 321296  IDARUBICIN HYDROCHLORIDE    Compound(42890)
# 321297  IDARUBICIN HYDROCHLORIDE    Compound(42890)
# 321298  IDARUBICIN HYDROCHLORIDE    Compound(42890)
# 321299  IDARUBICIN HYDROCHLORIDE    Compound(42890)
#
# [321300 rows x 10 columns]

# %%
temp2_dc[['drug1','drug2','CELLNAME',\
          'COMBO_SCORE','pubchemID_x','pubchemID_y']].to_csv("long_DTP_NCI60_ALMANAC_COMBO_SCORE_withID.csv")
