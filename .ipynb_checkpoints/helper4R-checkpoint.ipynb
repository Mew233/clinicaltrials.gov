# %%
import pubchempy as pcp
import pandas as pd

# %%
compoundnames = pd.read_csv("ComboCompoundNames_small.txt", sep='\t')

# %%
for x in set(compoundnames['Drug'].unique()): print(x)

# %%
# 用pubchem搜索ichikey
#https://pubchem.ncbi.nlm.nih.gov/idexchange/idexchange.cgi

# %%
helper4ichikey = pd.read_csv("helper4R.txt",sep='\t', header=None)
helper4ichikey.columns = ['drug_name',"ichikey"]
helper4ichikey = helper4ichikey.drop_duplicates(subset=['drug_name'], keep="first")

# %%
helper4ichikey
# Out:
#                     drug_name                      ichikey
# 0                 Clofarabine  WDDPHFBMKLOVOX-AYQXTPAHSA-N
# 1    Raloxifene hydrochloride  BKXVVCILCIUCLG-UHFFFAOYSA-N
# 2                  Nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N
# 3                   Etoposide  VJJPUSNTGOMMGY-MRVIYFEKSA-N
# 4        Lapatinib ditosylate  UWYXLGUQQFPJRI-UHFFFAOYSA-N
# ..                        ...                          ...
# 178       Triethylenemelamine  IUCJMVBFZDHPDX-UHFFFAOYSA-N
# 179               Azacitidine  NMUSYJAQQFHJEW-KVTDHHQDSA-N
# 180                  Busulfan  COVZYZSDYWQREU-UHFFFAOYSA-N
# 181   Topotecan hydrochloride  DGHHQBMTXTWTJV-BQAIUKQQSA-N
# 182  Quinacrine hydrochloride  UDKVBVICMUEIKS-UHFFFAOYSA-N
#
# [104 rows x 2 columns]

# %%
for x in helper4ichikey['ichikey']: print(x)
    # 用classifire搜索
    #https://cfb.fiehnlab.ucdavis.edu/

# %%
batch_classifire = pd.read_csv("classyfire_.csv")

# %%
pd.merge(helper4ichikey,batch_classifire,left_on='ichikey',right_on='InChIKey')
# Out:
#                     drug_name                      ichikey  \
# 0                 Clofarabine  WDDPHFBMKLOVOX-AYQXTPAHSA-N
# 1    Raloxifene hydrochloride  BKXVVCILCIUCLG-UHFFFAOYSA-N
# 2                  Nelarabine  IXOXBSCIXZEQEQ-UHTZMRCNSA-N
# 3                   Etoposide  VJJPUSNTGOMMGY-MRVIYFEKSA-N
# 4        Lapatinib ditosylate  UWYXLGUQQFPJRI-UHFFFAOYSA-N
# ..                        ...                          ...
# 99        Triethylenemelamine  IUCJMVBFZDHPDX-UHFFFAOYSA-N
# 100               Azacitidine  NMUSYJAQQFHJEW-KVTDHHQDSA-N
# 101                  Busulfan  COVZYZSDYWQREU-UHFFFAOYSA-N
# 102   Topotecan hydrochloride  DGHHQBMTXTWTJV-BQAIUKQQSA-N
# 103  Quinacrine hydrochloride  UDKVBVICMUEIKS-UHFFFAOYSA-N
#
#                         InChIKey ClassyFy Status            Kingdom  \
# 0    WDDPHFBMKLOVOX-AYQXTPAHSA-N       Completed  Organic compounds
# 1    BKXVVCILCIUCLG-UHFFFAOYSA-N       Completed  Organic compounds
# 2    IXOXBSCIXZEQEQ-UHTZMRCNSA-N       Completed  Organic compounds
# 3    VJJPUSNTGOMMGY-MRVIYFEKSA-N       Completed  Organic compounds
# 4    UWYXLGUQQFPJRI-UHFFFAOYSA-N       Completed  Organic compounds
# ..                           ...             ...                ...
# 99   IUCJMVBFZDHPDX-UHFFFAOYSA-N       Completed  Organic compounds
# 100  NMUSYJAQQFHJEW-KVTDHHQDSA-N       Completed  Organic compounds
# 101  COVZYZSDYWQREU-UHFFFAOYSA-N       Completed  Organic compounds
# 102  DGHHQBMTXTWTJV-BQAIUKQQSA-N       Completed  Organic compounds
# 103  UDKVBVICMUEIKS-UHFFFAOYSA-N       Completed  Organic compounds
#
#                                     Superclass  \
# 0      Nucleosides, nucleotides, and analogues
# 1                     Organic oxygen compounds
# 2      Nucleosides, nucleotides, and analogues
# 3    Lignans, neolignans and related compounds
# 4                 Organoheterocyclic compounds
# ..                                         ...
# 99                  Organic nitrogen compounds
# 100                   Organic oxygen compounds
# 101              Organic acids and derivatives
# 102                  Alkaloids and derivatives
# 103               Organoheterocyclic compounds
#
#                                       Class  \
# 0                        Purine nucleosides
# 1                    Organooxygen compounds
# 2                        Purine nucleosides
# 3                           Lignan lactones
# 4                         Diazanaphthalenes
# ..                                      ...
# 99                 Organonitrogen compounds
# 100                  Organooxygen compounds
# 101  Organic sulfonic acids and derivatives
# 102                           Camptothecins
# 103              Quinolines and derivatives
#
#                                       Subclass  \
# 0               Purine 2'-deoxyribonucleosides
# 1                           Carbonyl compounds
# 2                                          NaN
# 3                             Podophyllotoxins
# 4                                Benzodiazines
# ..                                         ...
# 99                                      Amines
# 100  Carbohydrates and carbohydrate conjugates
# 101       Organosulfonic acids and derivatives
# 102                                        NaN
# 103                            Benzoquinolines
#
#                      Parent Level 1            Parent Level 2  \
# 0    Purine 2'-deoxyribonucleosides                       NaN
# 1                           Ketones              Aryl ketones
# 2                Purine nucleosides                       NaN
# 3                  Podophyllotoxins                       NaN
# 4                      Quinazolines          Quinazolinamines
# ..                              ...                       ...
# 99                  Tertiary amines  Tertiary alkylarylamines
# 100              Glycosyl compounds            Glycosylamines
# 101      Organosulfonic acid esters                       NaN
# 102                   Camptothecins                       NaN
# 103                       Acridines                       NaN
#
#         Parent Level 3      Parent Level 4
# 0                  NaN                 NaN
# 1        Phenylketones  Aryl-phenylketones
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ..                 ...                 ...
# 99   Dialkylarylamines                 NaN
# 100                NaN                 NaN
# 101                NaN                 NaN
# 102                NaN                 NaN
# 103                NaN                 NaN
#
# [104 rows x 12 columns]

# %% [markdown]
# ### convert web crawler drugs/ almanac combo score's drugs to pubchemID

# %%
dcdb_score = pd.read_csv("dcdb_crawler_almanac.csv")

# %%
dcdb_score
# Out:
#                            drug1                drug2    cellName       HSA  \
# 0       CYTARABINE HYDROCHLORIDE            NSC733504    NCI-H226  0.066454
# 1                 MERCAPTOPURINE  ANTIBIOTIC AY 22989       K-562 -4.495244
# 2                     MITOMYCINE            ELOXATIN     CCRF-CEM -6.434438
# 3                    CHEMBL17639          IXABEPILONE  MDA-MB-468  1.353194
# 4       CYTARABINE HYDROCHLORIDE     ARSENIC TRIOXIDE      IGROV1  4.660007
# ...                          ...                  ...         ...       ...
# 311593                  THIOTEPA            NSC256439    UACC-257  2.588019
# 311594                    EMCYT             NSC256439   NCI-H322M  6.813287
# 311595                   GEMZAR     ADM HYDROCHLORIDE    NCI-H460 -4.344667
# 311596   TOPOTECAN HYDROCHLORIDE    ADM HYDROCHLORIDE    NCI-H460 -8.915629
# 311597                  IMATINIB            NSC256439    NCI-H226  3.917717
#
#             Bliss      Loewe       ZIP
# 0        1.101240  -3.895015 -0.672448
# 1       -0.251519  -4.067010  1.247770
# 2       -6.028172 -11.669370 -2.285056
# 3        0.542944  -2.536074  0.061003
# 4       -1.378867   3.337762 -2.848913
# ...           ...        ...       ...
# 311593  -0.496970  -9.415246 -2.490874
# 311594   7.759615   3.503649  0.713142
# 311595 -10.310261  -5.188500 -7.693727
# 311596 -12.171412  -9.557492 -5.515893
# 311597   4.799775 -42.890835  3.636956
#
# [311598 rows x 7 columns]

# %%
def get_uniquedrug(subsetdf):
    drug_list = []
    drug1_dc = subsetdf["drug1"].unique()
    drug2_dc = subsetdf["drug2"].unique()
    
    drug_list.append(set(drug1_dc))
    drug_list.append(set(drug2_dc))
    return drug_list

# %%
drug_list = get_uniquedrug(dcdb_score)
# One-Liner to union a list of sets
drug_list_set = set().union(*drug_list)

# %%
len(drug_list_set)
# Out:
# 103

# %%
# 1. get pubchemID for each unique drug by using PubChem API

def get_compounds(a_drug):
    return pcp.get_compounds(a_drug, 'name',listkey_count=1)

def get_pubchemID(drug_list_set):
    chemID_list = [ get_compounds(x)[0] if len(get_compounds(x))>0 else "" for x in drug_list_set ]
    print(x for x in drug_list_set)
    return chemID_list

chemID_list = get_pubchemID(drug_list_set)
pubchemIDmapping = pd.DataFrame({
    'drug_name': list(drug_list_set),
    'pubchemID': chemID_list
})
pubchemIDmapping['pubchemID'] = pubchemIDmapping['pubchemID'].astype(str)
# Out:
# <generator object get_pubchemID.<locals>.<genexpr> at 0x7fdaa92d7cd0>

# %%
pubchemIDmapping
# Out:
#                drug_name           pubchemID
# 0               THIOTEPA      Compound(5453)
# 1    ANTIBIOTIC AY 22989   Compound(5284616)
# 2             34793-34-5  Compound(13988706)
# 3                GEMZAR      Compound(60749)
# 4              NILOTINIB    Compound(644241)
# ..                   ...                 ...
# 98       ZOLEDRONIC ACID     Compound(68740)
# 99            CRIZOTINIB  Compound(11626560)
# 100           VANDETANIB   Compound(3081361)
# 101                SN-38    Compound(104842)
# 102            TRETINOIN    Compound(444795)
#
# [103 rows x 2 columns]

# %%
temp1_dc = pd.merge(dcdb_score, pubchemIDmapping, left_on=['drug1'],right_on=['drug_name'])
temp2_dc = pd.merge(temp1_dc, pubchemIDmapping, left_on=['drug2'],right_on=['drug_name'])

# %%
temp2_dc[['drug1','drug2','cellName','HSA','Bliss','Loewe','ZIP','pubchemID_x','pubchemID_y']].to_csv("dcdb_crawler_almanac_withID.csv")

# %%
combo_score = pd.read_csv("long_DTP_NCI60_ALMANAC_COMBO_SCORE.csv")
combo_score
# Out:
#           NSC1    NSC2    CELLNAME  COMBO_SCORE         drug1        drug2
# 0          740     752        MCF7        -57.0  METHOTREXATE  THIOGUANINE
# 1          740     752  MDA-MB-231         19.0  METHOTREXATE  THIOGUANINE
# 2          740     752     HS 578T          8.0  METHOTREXATE  THIOGUANINE
# 3          740     752      BT-549        -33.0  METHOTREXATE  THIOGUANINE
# 4          740     752       T-47D        -89.0  METHOTREXATE  THIOGUANINE
# ...        ...     ...         ...          ...           ...          ...
# 321295  763371  761432      CAKI-1          5.0   RUXOLITINIB  CABAZITAXEL
# 321296  763371  761432     RXF 393         36.0   RUXOLITINIB  CABAZITAXEL
# 321297  763371  761432       SN12C         65.0   RUXOLITINIB  CABAZITAXEL
# 321298  763371  761432       TK-10         75.0   RUXOLITINIB  CABAZITAXEL
# 321299  763371  761432       UO-31         71.0   RUXOLITINIB  CABAZITAXEL
#
# [321300 rows x 6 columns]

# %%
drug_list = get_uniquedrug(combo_score)
# One-Liner to union a list of sets
drug_list_set = set().union(*drug_list)

# %%
len(drug_list_set)
# Out:
# 103

# %%
pcp.get_compounds("TEMOZOLOMIDE", 'name',listkey_count=1)
# Out:
# [Compound(5394)]

# %%
for x in drug_list_set:
    print(x)
    get_compounds(x)
# Out:
# THIOTEPA
# ANTIBIOTIC AY 22989
# 34793-34-5
# GEMZAR
# NILOTINIB
# IXABEPILONE
# CYTARABINE HYDROCHLORIDE
# FULVESTRANT
# CO-V
# AMIFOSTINE
# VEMURAFENIB
# PRALATREXATE
# NSC-127716
# ABIRATERONE
# BORTEZOMIB
# ACTINOMYCIN D
# 5-FU
# CARMUSTINE
# CYCLOPHOSPHAMIDE
# PIPOBROMAN
# CISPLATINO
# FLUDARABINE BASE
# NAVELBINE DITARTRATE
# MITOTANE
# CABAZITAXEL
# TAMOXIFEN CITRATE
# ADM HYDROCHLORIDE
# ANASTROZOLE
# BLEOMYCIN
# CELECOXIB
# ROMIDEPSIN
# METHOXSALEN
# EXEMESTANE
# DOCETAXEL
# EMCYT
# THIOGUANINE
# TRIETHYLENEMELAMINE
# CHLORAMBUCIL
# RALOXIFENE
# ARSENIC TRIOXIDE
# BUSULFAN
# MEGESTROL ACETATE
# TEMOZOLOMIDE
# ALLOPURINOL
# DAUNORUBICIN HYDROCHLORIDE
# NSC 85998
# VISMODEGIB
# BENDAMUSTINE HYDROCHLORIDE
# LAPATINIB
# CARBOPLATIN
# IFOSFAMIDE
# 5-FLUORO-2'-DEOXYURIDINE
# THALIDOMIDE
# ELOXATIN
# TENIPOSIDE
# PROCARBAZINE HYDROCHLORIDE
# LENALIDOMIDE
# PEMETREXED
# TOPOTECAN HYDROCHLORIDE
# IMATINIB
# NSC141540
# RUXOLITINIB
# ALTRETAMINE
# ZOLINZA
# MELPHALAN HYDROCHLORIDE
# METHOTREXATE
# VINBLASTINE SULFATE
# CHEMBL277800
# NSC256439
# CAPECITABINE
# LETROZOLE
# LOMUSTINE
# IMIQUIMOD
# DEXRAZOXANE
# AMINOLEVULINIC ACID HYDROCHLORIDE
# QUINACRINE HYDROCHLORIDE
# NSC733504
# SUNITINIB
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     270         log.debug('Request data: %s', postdata)
# --> 271         response = urlopen(apiurl, postdata)
#     272         return response
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 503: PUGREST.ServerBusy
#
# During handling of the above exception, another exception occurred:
#
# PubChemHTTPError                          Traceback (most recent call last)
# <ipython-input-46-4c7848c40a64> in <module>
#       1 for x in drug_list_set:
#       2     print(x)
# ----> 3     get_compounds(x)
#
# <ipython-input-17-a9ff044c7da1> in get_compounds(a_drug)
#       2
#       3 def get_compounds(a_drug):
# ----> 4     return pcp.get_compounds(a_drug, 'name',listkey_count=1)
#       5
#       6 def get_pubchemID(drug_list_set):
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in get_compounds(identifier, namespace, searchtype, as_dataframe, **kwargs)
#     319                          :class:`~pandas.DataFrame` and return that.
#     320     """
# --> 321     results = get_json(identifier, namespace, searchtype=searchtype, **kwargs)
#     322     compounds = [Compound(r) for r in results['PC_Compounds']] if results else []
#     323     if as_dataframe:
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in get_json(identifier, namespace, domain, operation, searchtype, **kwargs)
#     297     """Request wrapper that automatically parses JSON response and supresses NotFoundError."""
#     298     try:
# --> 299         return json.loads(get(identifier, namespace, domain, operation, 'JSON', searchtype, **kwargs).decode())
#     300     except NotFoundError as e:
#     301         log.info(e)
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in get(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     290                 response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     291     else:
# --> 292         response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     293     return response
#     294
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     272         return response
#     273     except HTTPError as e:
# --> 274         raise PubChemHTTPError(e)
#     275
#     276
#
# PubChemHTTPError: 'PUGREST.ServerBusy'

# %%
chemID_list = get_pubchemID(drug_list_set)
pubchemIDmapping = pd.DataFrame({
    'drug_name': list(drug_list_set),
    'pubchemID': chemID_list
})
pubchemIDmapping['pubchemID'] = pubchemIDmapping['pubchemID'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     270         log.debug('Request data: %s', postdata)
# --> 271         response = urlopen(apiurl, postdata)
#     272         return response
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 503: PUGREST.ServerBusy
#
# During handling of the above exception, another exception occurred:
#
# PubChemHTTPError                          Traceback (most recent call last)
# <ipython-input-39-ab3efd655a69> in <module>
# ----> 1 chemID_list = get_pubchemID(drug_list_set)
#       2 pubchemIDmapping = pd.DataFrame({
#       3     'drug_name': list(drug_list_set),
#       4     'pubchemID': chemID_list
#       5 })
#
# <ipython-input-17-a9ff044c7da1> in get_pubchemID(drug_list_set)
#       5
#       6 def get_pubchemID(drug_list_set):
# ----> 7     chemID_list = [ get_compounds(x)[0] if len(get_compounds(x))>0 else "" for x in drug_list_set ]
#       8     print(x for x in drug_list_set)
#       9     return chemID_list
#
# <ipython-input-17-a9ff044c7da1> in <listcomp>(.0)
#       5
#       6 def get_pubchemID(drug_list_set):
# ----> 7     chemID_list = [ get_compounds(x)[0] if len(get_compounds(x))>0 else "" for x in drug_list_set ]
#       8     print(x for x in drug_list_set)
#       9     return chemID_list
#
# <ipython-input-17-a9ff044c7da1> in get_compounds(a_drug)
#       2
#       3 def get_compounds(a_drug):
# ----> 4     return pcp.get_compounds(a_drug, 'name',listkey_count=1)
#       5
#       6 def get_pubchemID(drug_list_set):
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in get_compounds(identifier, namespace, searchtype, as_dataframe, **kwargs)
#     319                          :class:`~pandas.DataFrame` and return that.
#     320     """
# --> 321     results = get_json(identifier, namespace, searchtype=searchtype, **kwargs)
#     322     compounds = [Compound(r) for r in results['PC_Compounds']] if results else []
#     323     if as_dataframe:
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in get_json(identifier, namespace, domain, operation, searchtype, **kwargs)
#     297     """Request wrapper that automatically parses JSON response and supresses NotFoundError."""
#     298     try:
# --> 299         return json.loads(get(identifier, namespace, domain, operation, 'JSON', searchtype, **kwargs).decode())
#     300     except NotFoundError as e:
#     301         log.info(e)
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in get(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     290                 response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     291     else:
# --> 292         response = request(identifier, namespace, domain, operation, output, searchtype, **kwargs).read()
#     293     return response
#     294
#
# /opt/miniconda3/envs/synergyy/lib/python3.7/site-packages/pubchempy.py in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     272         return response
#     273     except HTTPError as e:
# --> 274         raise PubChemHTTPError(e)
#     275
#     276
#
# PubChemHTTPError: 'PUGREST.ServerBusy'

# %%
pubchemIDmapping
# Out:
#                drug_name           pubchemID
# 0               THIOTEPA      Compound(5453)
# 1    ANTIBIOTIC AY 22989   Compound(5284616)
# 2             34793-34-5  Compound(13988706)
# 3                GEMZAR      Compound(60749)
# 4              NILOTINIB    Compound(644241)
# ..                   ...                 ...
# 98       ZOLEDRONIC ACID     Compound(68740)
# 99            CRIZOTINIB  Compound(11626560)
# 100           VANDETANIB   Compound(3081361)
# 101                SN-38    Compound(104842)
# 102            TRETINOIN    Compound(444795)
#
# [103 rows x 2 columns]

# %%
temp1_dc = pd.merge(dcdb_score, pubchemIDmapping, left_on=['drug1'],right_on=['drug_name'])
temp2_dc = pd.merge(temp1_dc, pubchemIDmapping, left_on=['drug2'],right_on=['drug_name'])
